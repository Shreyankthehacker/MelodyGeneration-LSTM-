# %%
import kagglehub

# !mkdir data

path = kagglehub.dataset_download("dattuan/deutschl-kernscores")

print("Path to dataset files:", path)
# Out:
# mkdir: cannot create directory ‘data’: File exists
# Warning: Looks like you're using an outdated `kagglehub` version (installed: 0.3.7), please consider upgrading to the latest version (0.3.8).
# Path to dataset files: /root/.cache/kagglehub/datasets/dattuan/deutschl-kernscores/versions/1

# %%
# !cp -r "/root/.cache/kagglehub/datasets/dattuan/deutschl-kernscores/versions/1" "/content/data/"

# %%
import os
import music21 as m21

# %%
# !mkdir dataset

# %%
ACCEPTALE_DURATION = [0.25,0.5,0.75,1.0,1.5,2,3,4]
DATASET_PATH = "/content/data/1"

SAVE_DIR = "/content/dataset"
SINGLE_FILE = "/content/singlefile.txt"


def load_songs_in_kern(dataset_path):
  songs = []
  for path , subdir,files in os.walk(dataset_path):
    for file in files:
      if file.endswith("krn"):
        song = m21.converter.parse(os.path.join(path,file))
        #m21 is used for converting file from one format to another (this is one of the use of that library)
        songs.append(song)
  return songs




def has_acceptable_durations(song , ACCEPTALE_DURATION):
  for note in song.flat.notesAndRests:
    if note.duration.quarterLength not in ACCEPTALE_DURATION:
      return False
  return True


def transpose(song):
  # get kety from song

  parts = song.getElementsByClass(m21.stream.Part)
  measure_part0 = parts[0].getElementsByClass(m21.stream.Measure)
  key = measure_part0[0][4]

  # estimate key from music21
  if not isinstance(key,m21.key.Key):
    key = song.analyze("key")

  # get interval for the transposition
  if key.mode == "major":
    interval = m21.interval.Interval(key.tonic,m21.pitch.Pitch("C"))
  elif key.mode == "minor":
    interval = m21.interval.Interval(key.tonic,m21.pitch.Pitch("A"))

  # transpose the song by calculated interval
  print(key)
  transposed_song = song.transpose(interval)
  return transposed_song


def encode_songs(song,time_step = 0.2):
  encoded_song = []
  # returns song encoded in string
  for event in song.flat.notesAndRests:

    if isinstance(event , m21.note.Note):
      symbol = event.pitch.midi
    elif isinstance(event,m21.note.Rest):
      symbol = "r"
    steps = int(event.duration.quarterLength/time_step)

    for step in range(steps):
      if step == 0:
        encoded_song.append(symbol)
      else:
        encoded_song.append("_")

  encoded_song = " ".join(map(str,encoded_song))
  return encoded_song


def preprocess(dataset_path):
  #load the folk songs
  print("Loadingggg...........")
  songs = load_songs_in_kern(dataset_path )
  print(f"Loaded {len(songs)} songs")

  #filter the songs that have non acceptable durations
  for i,song in enumerate(songs):
    if not has_acceptable_durations(song,ACCEPTALE_DURATION):
      continue

    #transpose c major / a minor
    t_song = transpose(song)

    #encode songs with music time series representation
    encoded_song = encode_songs(t_song)

    #save songs to single text file
    save_path = os.path.join(SAVE_DIR,str(i))
    with open(save_path,"w") as f:
      f.write(encoded_song)

def create_single_file(dataset_path , single_file_path,seq_length = 64):
  new_song_delimiter = "/ " * seq_length
  songs = ""
    # load encoded songs
  for  path,_,files in os.walk(dataset_path):
    for file in files:
      file_path = os.path.join(path,file)
      song = open(file_path,"r").read()

      songs = songs + song + " " + new_song_delimiter

  songs = songs[:-1]


  # save string that contains all dataset
  with open(single_file_path,"w") as f:
    f.write(songs)

  return songs

# %%
preprocess(DATASET_PATH)
# Out:
# Loadingggg...........
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*M5/1%%%2+3%') at position 52 for spine None: Cannot parse this file -- this error often comes up if the musicxml pickled file is out of date after a change in musicxml/__init__.py . Clear your temp directory of .p and .p.gz files and try again. Time Signature: 5/1%%%2+3%
# humdrum.spineParser: WARNING: Error in parsing event ('*MFREI4/4') at position 7 for spine None: Incorrect meter: *MFREI4/4 found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 8 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 11 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 11 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 11 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 11 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# humdrum.spineParser: WARNING: Error in parsing event ('*MX') at position 10 for spine None: Incorrect meter: *MX found
# Loaded 5365 songs
# G major
# D major
# F major
# G major
# G major
# F major
# D major
# C major
# A- major
# G major
# B- major
# D major
# G major
# C major
# /usr/local/lib/python3.11/dist-packages/music21/stream/base.py:3689: Music21DeprecationWarning: .flat is deprecated.  Call .flatten() instead
#   return self.iter().getElementsByClass(classFilterList)
# F major
# G major
# G major
# G major
# D major
# G major
# E- major
# G major
# F major
# G major
# C major
# G major
# C major
# G major
# F major
# D major
# G major
# D major
# C major
# C major
# G major
# G major
# C major
# F major
# F major
# G major
# G major
# G major
# D major
# G major
# G major
# D major
# C major
# G major
# C major
# G major
# D major
# A major
# g minor
# G major
# B- major
# G major
# E- major
# F major
# g minor
# G major
# e minor
# G major
# G major
# B- major
# G major
# G major
# A major
# F major
# G major
# F major
# a minor
# F major
# C major
# C major
# C major
# G major
# A major
# F major
# D major
# G major
# G major
# G major
# G major
# G major
# D major
# F major
# G major
# F major
# G major
# G major
# G major
# G major
# G major
# D major
# F major
# G major
# C major
# G major
# G major
# A major
# G major
# G major
# C major
# F major
# E major
# F major
# C major
# B- major
# D major
# F major
# G major
# C major
# A major
# C major
# C major
# F major
# G major
# C major
# B- major
# G major
# D major
# G major
# E major
# F major
# D major
# G major
# C major
# F major
# d minor
# B- major
# G major
# E- major
# G major
# C major
# G major
# E major
# G major
# F major
# B- major
# C major
# C major
# G major
# G major
# E- major
# E- major
# G major
# d minor
# B- major
# G major
# G major
# F major
# C major
# a minor
# C major
# F major
# F major
# E major
# F major
# G major
# F major
# F major
# F major
# g minor
# c minor
# G major
# C major
# C major
# G major
# C major
# B- major
# F major
# D major
# B- major
# F major
# F major
# F major
# A major
# G major
# F major
# G major
# C major
# G major
# B- major
# G major
# A major
# F major
# G major
# a minor
# G major
# F major
# G major
# G major
# C major
# G major
# F major
# A major
# F major
# C major
# D major
# E major
# D major
# F major
# G major
# E- major
# G major
# C major
# F major
# G major
# G major
# G major
# C major
# F major
# F major
# C major
# C major
# G major
# F major
# G major
# A major
# F major
# G major
# a minor
# G major
# G major
# F major
# F major
# G major
# G major
# G major
# G major
# G major
# D major
# D major
# a minor
# F major
# g minor
# F major
# F major
# F major
# F major
# a minor
# g minor
# A major
# F major
# G major
# F major
# G major
# F major
# d minor
# D major
# G major
# A major
# G major
# A major
# g minor
# g minor
# F major
# d minor
# d minor
# d minor
# d minor
# F major
# g minor
# g minor
# G major
# g minor
# F major
# F major
# g minor
# F major
# C major
# G major
# F major
# C major
# F major
# F major
# A major
# G major
# G major
# C major
# G major
# g minor
# d minor
# A major
# B- major
# d minor
# g minor
# g minor
# g minor
# e minor
# f minor
# d minor
# g minor
# F major
# F major
# g minor
# g minor
# d minor
# e minor
# a minor
# g minor
# F major
# F major
# F major
# C major
# d minor
# G major
# g minor
# F major
# A major
# g minor
# F major
# g minor
# G major
# A major
# F major
# g minor
# F major
# G major
# F major
# G major
# d minor
# d minor
# F major
# F major
# F major
# F major
# g minor
# F major
# F major
# e minor
# F major
# G major
# G major
# d minor
# d minor
# F major
# a minor
# F major
# F major
# g minor
# G major
# g minor
# G major
# a minor
# g minor
# D major
# d minor
# e minor
# F major
# C major
# C major
# G major
# g minor
# C major
# C major
# g minor
# F major
# F major
# C major
# F major
# g minor
# a minor
# F major
# F major
# F major
# G major
# F major
# g minor
# G major
# C major
# G major
# F major
# F major
# D major
# g minor
# C major
# A- major
# G major
# G major
# D major
# F major
# F major
# D major
# E major
# A major
# F major
# G major
# A major
# C major
# c minor
# E- major
# C major
# B- major
# E- major
# d minor
# G major
# E major
# D major
# E- major
# D major
# D major
# G major
# G major
# G major
# f minor
# G major
# b- minor
# A major
# A major
# E- major
# E- major
# G major
# B- major
# C major
# G major
# e minor
# D major
# C major
# E major
# G major
# A- major
# G major
# E- major
# D major
# G major
# B- major
# F major
# G major
# E- major
# C major
# G major
# A major
# E- major
# G major
# G major
# C major
# A major
# G major
# G major
# G major
# G major
# D major
# D major
# C major
# G major
# B- major
# g minor
# C major
# C major
# E- major
# A- major
# B- major
# E- major
# B- major
# C major
# A major
# G major
# D major
# G major
# G major
# A major
# C major
# F major
# E major
# G major
# F major
# F major
# D major
# D major
# F major
# A major
# C major
# G major
# F major
# E- major
# C major
# C major
# G major
# G major
# A major
# G major
# F major
# E- major
# D major
# F major
# E- major
# A major
# E- major
# G major
# B- major
# C major
# A major
# D- major
# A major
# G major
# F major
# C major
# B- major
# E major
# C major
# F major
# D major
# A major
# F major
# B- major
# F major
# F major
# F major
# D major
# B- major
# G major
# F major
# A major
# F major
# C major
# F major
# F major
# F major
# A major
# D major
# E major
# G major
# B- major
# D major
# G major
# F major
# E- major
# C major
# G major
# G major
# F major
# F major
# F major
# A major
# D major
# A major
# D major
# F major
# D major
# C major
# G major
# G major
# F major
# G major
# A major
# G major
# F major
# F major
# F major
# F major
# E- major
# C major
# C major
# C major
# G major
# G major
# G major
# F major
# G major
# C major
# G major
# D major
# C major
# F major
# F major
# G major
# G major
# E major
# E- major
# B- major
# G major
# G major
# G major
# C major
# B- major
# D major
# A major
# E major
# B- major
# E- major
# F major
# B- major
# F major
# G major
# C major
# D major
# B- major
# F major
# C major
# B- major
# C major
# F major
# G major
# F major
# C major
# A major
# C major
# A major
# E- major
# e minor
# F major
# G major
# C major
# C major
# B- major
# C major
# E major
# F major
# C major
# C major
# E major
# F major
# A major
# C major
# F major
# G major
# E- major
# E- major
# C major
# A major
# G major
# G major
# C major
# A major
# A major
# E major
# C major
# C major
# C major
# E- major
# E- major
# C major
# C major
# C major
# D major
# E- major
# C major
# B- major
# B- major
# C major
# B- major
# B- major
# F major
# G major
# F major
# D major
# G major
# E- major
# D major
# C major
# E major
# F major
# a minor
# B- major
# C major
# E major
# G major
# E- major
# B- major
# E major
# C major
# A major
# G major
# G major
# B- major
# A- major
# G major
# G major
# G major
# A- major
# B- major
# E- major
# A major
# A major
# C major
# F major
# D major
# F major
# G major
# a minor
# G major
# a minor
# D major
# G major
# F major
# C major
# E- major
# C major
# C major
# E major
# A major
# g minor
# E- major
# C major
# D major
# G major
# C major
# D major
# f minor
# F major
# A major
# A major
# E major
# D major
# F major
# B- major
# G major
# F major
# F major
# B- major
# D major
# C major
# F major
# G major
# F major
# D major
# F major
# D major
# E major
# c minor
# A- major
# E major
# B- major
# F major
# B- major
# G major
# C major
# B- major
# C major
# C major
# G major
# E- major
# E- major
# E- major
# E- major
# F major
# A- major
# B- major
# C major
# F major
# F major
# F major
# C major
# G major
# G major
# D major
# C major
# G major
# B- major
# F major
# A major
# G major
# G major
# G major
# B- major
# C major
# G major
# a minor
# C major
# D major
# B- major
# F major
# D major
# g minor
# G major
# C major
# D major
# C major
# b- minor
# D major
# F major
# E- major
# B- major
# G major
# C major
# G major
# C major
# C major
# A major
# F major
# G major
# G major
# B- major
# E major
# C major
# G major
# C major
# G major
# C major
# F major
# F major
# G major
# D major
# C major
# D major
# E- major
# F major
# F major
# C major
# B- major
# D major
# F major
# G major
# E- major
# C major
# G major
# F major
# C major
# B- major
# F major
# B- major
# E major
# F major
# F major
# G major
# A major
# C major
# A major
# D major
# D major
# F major
# e minor
# C major
# E- major
# F major
# D major
# D major
# F major
# A major
# C major
# F major
# G major
# F major
# G major
# E- major
# G major
# G major
# C major
# C major
# F major
# a minor
# D major
# G major
# G major
# E major
# A major
# G major
# F major
# B- major
# A major
# F major
# F major
# F major
# C major
# E major
# E- major
# F major
# F major
# E- major
# D major
# G major
# G major
# D major
# C major
# D major
# G major
# G major
# C major
# C major
# B- major
# G major
# C major
# D major
# B- major
# E- major
# C major
# C major
# F major
# E- major
# A major
# C major
# G major
# A major
# G major
# F major
# C major
# G major
# G major
# A major
# G major
# E- major
# E- major
# B- major
# D major
# G major
# G major
# C major
# A major
# B- major
# E- major
# C major
# F major
# A major
# B- major
# C major
# A major
# A major
# F major
# E- major
# C major
# B- major
# F major
# C major
# G major
# F major
# A- major
# B- major
# G major
# B- major
# G major
# F major
# E major
# A major
# A major
# F major
# B- major
# G major
# E- major
# C major
# A major
# F major
# g minor
# F major
# A major
# A major
# e minor
# G major
# F major
# g minor
# f minor
# a minor
# G major
# a minor
# B- major
# e minor
# G major
# B- major
# A major
# G major
# E major
# F major
# E- major
# G major
# G major
# C major
# D major
# C major
# G major
# e minor
# A major
# a minor
# C major
# D major
# A major
# a minor
# G major
# a minor
# F major
# F major
# D major
# A major
# a minor
# C major
# G major
# F major
# F major
# D major
# C major
# G major
# B- major
# F major
# c minor
# G major
# A- major
# G major
# C major
# F major
# G major
# G major
# F major
# E- major
# G major
# d minor
# g minor
# A major
# g minor
# G major
# G major
# F major
# D major
# g minor
# b- minor
# F major
# g minor
# F major
# E major
# G major
# E major
# C major
# C major
# G major
# B- major
# G major
# B- major
# G major
# G major
# F major
# A major
# G major
# G major
# C major
# d minor
# G major
# G major
# D major
# D major
# G major
# G major
# g minor
# G major
# C major
# C major
# G major
# a minor
# G major
# e minor
# C major
# F major
# G major
# G major
# a minor
# F major
# g minor
# C major
# G major
# F major
# C major
# G major
# C major
# G major
# A major
# G major
# g minor
# F major
# F major
# d minor
# A major
# e minor
# G major
# d minor
# B- major
# g minor
# a minor
# e minor
# F major
# B- major
# G major
# E major
# F major
# c minor
# E major
# F major
# F major
# A- major
# F major
# G major
# F major
# G major
# F major
# C major
# D major
# C major
# F major
# G major
# g minor
# F major
# C major
# F major
# C major
# e minor
# g minor
# E major
# F major
# B- major
# F major
# B- major
# g minor
# G major
# g minor
# d minor
# F major
# B- major
# C major
# A- major
# B- major
# F major
# G major
# A- major
# A major
# G major
# g minor
# F major
# A major
# g minor
# F major
# C major
# G major
# A major
# b- minor
# B- major
# G major
# c minor
# a minor
# E major
# G major
# G major
# d minor
# A- major
# G major
# d minor
# F major
# F major
# A major
# A major
# F major
# D major
# G major
# G major
# a minor
# F major
# G major
# F major
# D major
# C major
# D major
# E major
# e minor
# a minor
# B- major
# F major
# D major
# g minor
# G major
# G major
# G major
# A- major
# A major
# g minor
# B- major
# G major
# F major
# F major
# G major
# G major
# C major
# G major
# F major
# G major
# A major
# g minor
# G major
# a minor
# f minor
# G major
# G major
# C major
# G major
# G major
# A major
# G major
# B- major
# e minor
# E- major
# E- major
# D major
# a minor
# B- major
# E- major
# G major
# C major
# G major
# F major
# G major
# E major
# A- major
# G major
# G major
# G major
# A major
# G major
# B- major
# D major
# G major
# G major
# a minor
# F major
# C major
# G major
# G major
# G major
# F major
# e minor
# C major
# a minor
# G major
# G major
# e minor
# G major
# C major
# g minor
# B- major
# d minor
# G major
# A major
# g minor
# A- major
# a minor
# C major
# g minor
# A major
# C major
# e minor
# F major
# C major
# C major
# G major
# A major
# F major
# G major
# B- major
# F major
# A major
# G major
# G major
# A- major
# E major
# C major
# F major
# D major
# C major
# b- minor
# d minor
# G major
# a minor
# g minor
# F major
# e minor
# F major
# G major
# g minor
# G major
# C major
# B- major
# B- major
# G major
# G major
# C major
# D major
# G major
# B- major
# A major
# A major
# A- major
# B- major
# g minor
# f minor
# A- major
# D major
# C major
# C major
# G major
# D major
# E- major
# D major
# B- major
# B- major
# g minor
# G major
# C major
# d minor
# G major
# g minor
# G major
# B- major
# g minor
# C major
# c minor
# F major
# F major
# E- major
# E- major
# G major
# F major
# C major
# A major
# G major
# F major
# B- major
# G major
# C major
# F major
# G major
# f minor
# e minor
# B- major
# F major
# a minor
# G major
# D major
# F major
# G major
# G major
# F major
# e minor
# g minor
# C major
# C major
# C major
# C major
# A major
# d minor
# G major
# B- major
# g minor
# G major
# g minor
# g minor
# G major
# g minor
# C major
# e minor
# g minor
# G major
# G major
# G major
# A major
# A major
# G major
# C major
# G major
# D major
# F major
# D major
# g minor
# A major
# B- major
# F major
# F major
# G major
# F major
# A major
# F major
# g minor
# F major
# a minor
# F major
# G major
# F major
# g minor
# F major
# A major
# G major
# B- major
# g minor
# F major
# F major
# G major
# G major
# C major
# B- major
# d minor
# g minor
# d minor
# G major
# c minor
# A major
# G major
# C major
# a minor
# B- major
# g minor
# D major
# B- major
# G major
# a minor
# D major
# G major
# g minor
# G major
# g minor
# G major
# F major
# D major
# B- major
# A major
# a minor
# F major
# g minor
# F major
# G major
# G major
# g minor
# F major
# F major
# E- major
# A major
# D major
# C major
# B- major
# F major
# C major
# B- major
# G major
# A major
# g minor
# C major
# B- major
# A major
# D major
# G major
# E major
# G major
# G major
# F major
# e minor
# A major
# F major
# F major
# D major
# a minor
# C major
# B- major
# A major
# G major
# g minor
# g minor
# F major
# C major
# G major
# a minor
# g minor
# a minor
# c minor
# C major
# G major
# B- major
# G major
# G major
# A major
# G major
# G major
# G major
# A major
# C major
# F major
# G major
# E- major
# B- major
# G major
# C major
# D major
# D major
# C major
# g minor
# D major
# C major
# G major
# G major
# C major
# F major
# E major
# G major
# G major
# G major
# g minor
# g minor
# F major
# C major
# f minor
# C major
# e minor
# G major
# G major
# e minor
# F major
# g minor
# C major
# A major
# F major
# G major
# a minor
# F major
# E major
# F major
# D major
# G major
# G major
# B- major
# F major
# G major
# a minor
# G major
# C major
# a minor
# G major
# B- major
# G major
# e minor
# C major
# G major
# C major
# D major
# g minor
# A major
# G major
# A major
# F major
# G major
# F major
# B- major
# B- major
# C major
# F major
# A major
# E- major
# F major
# F major
# E- major
# F major
# D major
# A major
# E- major
# F major
# F major
# A major
# C major
# B- major
# C major
# D major
# E- major
# F major
# C major
# C major
# E- major
# C major
# F major
# F major
# B- major
# B- major
# C major
# B- major
# B- major
# F major
# E- major
# D major
# C major
# F major
# C major
# C major
# A major
# D major
# B- major
# C major
# G major
# A major
# F major
# C major
# E major
# F major
# B- major
# C major
# G major
# C major
# C major
# E- major
# g minor
# G major
# G major
# G major
# F major
# G major
# G major
# G major
# G major
# D major
# G major
# D major
# G major
# E- major
# G major
# B- major
# E- major
# C major
# c minor
# C major
# G major
# G major
# D major
# G major
# G major
# B- major
# F major
# G major
# G major
# E- major
# C major
# G major
# B- major
# A major
# G major
# D major
# F major
# C major
# G major
# G major
# C major
# E- major
# G major
# C major
# G major
# A major
# G major
# C major
# G major
# C major
# A major
# F major
# G major
# E- major
# G major
# C major
# F major
# G major
# a minor
# G major
# G major
# B- major
# E- major
# G major
# C major
# C major
# G major
# C major
# D major
# g minor
# G major
# E- major
# G major
# D major
# E- major
# E- major
# B- major
# A major
# B- major
# C major
# C major
# C major
# E major
# F major
# G major
# E- major
# E- major
# A major
# F major
# D major
# B- major
# C major
# C major
# C major
# A major
# A major
# E major
# F major
# C major
# G major
# G major
# D major
# G major
# G major
# F major
# F major
# G major
# B- major
# G major
# B- major
# G major
# G major
# G major
# E- major
# C major
# E- major
# G major
# g minor
# F major
# e minor
# G major
# F major
# D major
# F major
# C major
# g minor
# D major
# B- major
# e minor
# F major
# B- major
# F major
# B- major
# F major
# C major
# F major
# F major
# G major
# B- major
# F major
# F major
# C major
# F major
# F major
# D major
# C major
# F major
# G major
# B- major
# G major
# G major
# d minor
# B- major
# E- major
# G major
# F major
# F major
# C major
# C major
# G major
# C major
# G major
# G major
# G major
# A major
# C major
# D major
# G major
# F major
# G major
# C major
# F major
# A major
# B- major
# E- major
# G major
# B- major
# G major
# A major
# G major
# G major
# A major
# E- major
# F major
# G major
# G major
# D major
# g minor
# G major
# D major
# c minor
# C major
# C major
# F major
# d minor
# A major
# A major
# F major
# E- major
# C major
# G major
# G major
# D major
# C major
# D major
# C major
# G major
# F major
# F major
# G major
# G major
# G major
# F major
# C major
# C major
# F major
# G major
# d minor
# C major
# G major
# B- major
# F major
# C major
# C major
# e minor
# C major
# E- major
# G major
# D major
# G major
# B- major
# B- major
# G major
# C major
# D major
# G major
# F major
# E- major
# C major
# G major
# C major
# B- major
# C major
# C major
# B- major
# C major
# G major
# G major
# F major
# G major
# g minor
# C major
# B- major
# B- major
# F major
# D major
# C major
# E- major
# D major
# D major
# D major
# G major
# F major
# C major
# e minor
# G major
# F major
# F major
# C major
# G major
# D major
# D major
# G major
# B- major
# G major
# E- major
# E- major
# D major
# F major
# D major
# G major
# G major
# F major
# B- major
# A major
# F major
# D major
# E- major
# G major
# D major
# D major
# F major
# E- major
# B- major
# G major
# G major
# D major
# E- major
# G major
# G major
# G major
# G major
# E- major
# E- major
# C major
# G major
# F major
# E- major
# A major
# B- major
# G major
# D major
# G major
# G major
# C major
# F major
# G major
# E- major
# F major
# F major
# C major
# C major
# G major
# C major
# C major
# F major
# F major
# a minor
# F major
# F major
# D major
# G major
# F major
# F major
# C major
# G major
# C major
# C major
# F major
# D major
# F major
# G major
# C major
# A- major
# G major
# C major
# F major
# e minor
# B- major
# G major
# C major
# D major
# B- major
# G major
# C major
# E- major
# E- major
# D major
# F major
# G major
# G major
# G major
# F major
# F major
# D major
# C major
# C major
# C major
# B- major
# B- major
# D major
# A- major
# D major
# G major
# G major
# D major
# F major
# E- major
# D major
# C major
# a minor
# D major
# C major
# G major
# G major
# D major
# A major
# A major
# C major
# B- major
# G major
# E- major
# B- major
# D major
# E- major
# E- major
# G major
# A major
# F major
# E- major
# E- major
# G major
# G major
# G major
# F major
# F major
# C major
# G major
# A major
# B- major
# B- major
# D major
# C major
# A major
# C major
# D major
# E- major
# G major
# E major
# F major
# A major
# C major
# D major
# C major
# G major
# D major
# B- major
# A- major
# G major
# G major
# B- major
# C major
# C major
# C major
# D major
# E major
# G major
# F major
# G major
# G major
# E- major
# B- major
# D major
# G major
# C major
# G major
# F major
# C major
# G major
# C major
# B- major
# G major
# G major
# G major
# F major
# C major
# C major
# A major
# F major
# G major
# G major
# F major
# C major
# G major
# G major
# G major
# C major
# G major
# A major
# D major
# e minor
# A major
# b- minor
# D major
# B- major
# B- major
# G major
# F major
# B- major
# G major
# G major
# E- major
# C major
# F major
# B- major
# G major
# C major
# G major
# F major
# G major
# C major
# C major
# A major
# G major
# G major
# G major
# C major
# a minor
# G major
# C major
# A major
# B- major
# G major
# G major
# E- major
# A major
# C major
# D major
# B- major
# A major
# G major
# C major
# C major
# C major
# F major
# C major
# E- major
# C major
# C major
# B- major
# C major
# F major
# C major
# F major
# C major
# C major
# F major
# C major
# C major
# B- major
# G major
# F major
# A- major
# C major
# F major
# a minor
# G major
# E- major
# F major
# B- major
# B- major
# F major
# G major
# C major
# F major
# G major
# C major
# E- major
# E- major
# G major
# B- major
# A major
# G major
# A- major
# G major
# F major
# G major
# A major
# G major
# B- major
# C major
# D major
# B- major
# G major
# C major
# E major
# F major
# F major
# B- major
# G major
# B- major
# G major
# F major
# A major
# E- major
# B- major
# C major
# G major
# G major
# E- major
# G major
# G major
# C major
# E- major
# D major
# D major
# C major
# C major
# G major
# E- major
# D major
# C major
# D major
# e minor
# B- major
# C major
# C major
# d minor
# D major
# D major
# D major
# B- major
# B- major
# C major
# F major
# C major
# G major
# C major
# D major
# G major
# F major
# C major
# D major
# G major
# F major
# A major
# F major
# C major
# E- major
# G major
# E- major
# G major
# F major
# F major
# F major
# D major
# D major
# G major
# C major
# F major
# D major
# F major
# d minor
# d minor
# F major
# D major
# C major
# F major
# G major
# g minor
# F major
# g minor
# d minor
# d minor
# F major
# d minor
# C major
# G major
# G major
# F major
# F major
# g minor
# F major
# d minor
# F major
# d minor
# D major
# F major
# D major
# F major
# G major
# g minor
# g minor
# D major
# G major
# C major
# C major
# a minor
# G major
# G major
# g minor
# F major
# E major
# D major
# C major
# g minor
# F major
# F major
# F major
# C major
# g minor
# F major
# C major
# D major
# G major
# B- major
# g minor
# F major
# G major
# G major
# C major
# D major
# G major
# e minor
# D major
# d minor
# a minor
# g minor
# C major
# F major
# C major
# G major
# F major
# d minor
# d minor
# F major
# F major
# g minor
# d minor
# F major
# g minor
# C major
# C major
# F major
# F major
# C major
# D major
# F major
# g minor
# G major
# G major
# C major
# F major
# F major
# F major
# F major
# g minor
# B- major
# G major
# D major
# g minor
# g minor
# d minor
# F major
# e minor
# F major
# C major
# g minor
# F major
# A major
# d minor
# C major
# G major
# g minor
# F major
# G major
# g minor
# G major
# D major
# g minor
# d minor
# D major
# G major
# F major
# E- major
# F major
# G major
# C major
# F major
# G major
# G major
# D major
# G major
# C major
# G major
# B- major
# G major
# F major
# e minor
# G major
# F major
# F major
# B- major
# G major
# G major
# E- major
# F major
# C major
# F major
# G major
# F major
# G major
# G major
# G major
# G major
# F major
# G major
# D major
# B- major
# F major
# F major
# F major
# F major
# G major
# F major
# G major
# G major
# G major
# G major
# F major
# D major
# G major
# F major
# D major
# F major
# B- major
# G major
# G major
# G major
# G major
# C major
# F major
# F major
# B- major
# G major
# G major
# D major
# D major
# C major
# G major
# G major
# C major
# F major
# C major
# G major
# G major
# G major
# C major
# F major
# F major
# C major
# G major
# D major
# D major
# G major
# G major
# G major
# G major
# C major
# G major
# D major
# G major
# G major
# D major
# F major
# F major
# C major
# G major
# C major
# C major
# G major
# F major
# G major
# G major
# G major
# F major
# G major
# G major
# G major
# F major
# F major
# C major
# C major
# G major
# F major
# F major
# F major
# G major
# G major
# G major
# C major
# F major
# F major
# G major
# F major
# G major
# C major
# G major
# F major
# F major
# F major
# D major
# F major
# D major
# F major
# G major
# G major
# G major
# F major
# F major
# F major
# C major
# F major
# F major
# G major
# G major
# G major
# G major
# F major
# G major
# G major
# E- major
# C major
# C major
# F major
# C major
# B- major
# G major
# F major
# G major
# C major
# F major
# F major
# G major
# B- major
# D major
# F major
# G major
# G major
# F major
# G major
# C major
# D major
# G major
# D major
# G major
# G major
# G major
# G major
# F major
# G major
# C major
# G major
# F major
# G major
# F major
# D major
# G major
# F major
# G major
# F major
# F major
# E- major
# G major
# C major
# C major
# F major
# G major
# G major
# G major
# F major
# F major
# G major
# D major
# G major
# F major
# F major
# G major
# C major
# C major
# G major
# C major
# G major
# G major
# G major
# G major
# F major
# G major
# G major
# G major
# G major
# G major
# F major
# d minor
# F major
# F major
# G major
# G major
# D major
# G major
# F major
# g minor
# B- major
# B- major
# G major
# C major
# d minor
# G major
# F major
# G major
# F major
# B- major
# F major
# D major
# F major
# d minor
# F major
# A major
# G major
# G major
# G major
# F major
# G major
# C major
# C major
# E- major
# F major
# G major
# C major
# F major
# F major
# F major
# G major
# F major
# B- major
# G major
# G major
# G major
# A- major
# D major
# F major
# G major
# B- major
# C major
# C major
# C major
# F major
# A major
# B- major
# G major
# F major
# D major
# E- major
# G major
# G major
# G major
# D major
# G major
# F major
# G major
# G major
# G major
# G major
# F major
# F major
# F major
# G major
# F major
# F major
# G major
# F major
# B- major
# d minor
# G major
# G major
# g minor
# F major
# F major
# B- major
# F major
# F major
# G major
# G major
# G major
# F major
# G major
# C major
# G major
# G major
# B- major
# E major
# F major
# B- major
# E- major
# B- major
# G major
# A major
# F major
# D major
# c minor
# E- major
# F major
# B- major
# G major
# F major
# G major
# C major
# F major
# F major
# G major
# D major
# B- major
# G major
# G major
# G major
# D major
# B- major
# G major
# A major
# a minor
# F major
# G major
# G major
# B- major
# a minor
# F major
# G major
# A major
# F major
# F major
# C major
# C major
# G major
# F major
# G major
# F major
# G major
# G major
# G major
# C major
# E- major
# F major
# G major
# F major
# A major
# G major
# F major
# G major
# G major
# F major
# G major
# C major
# G major
# F major
# C major
# A major
# G major
# G major
# G major
# D major
# G major
# F major
# F major
# A major
# G major
# C major
# G major
# F major
# F major
# B- major
# B- major
# G major
# F major
# G major
# C major
# G major
# F major
# F major
# C major
# B- major
# B- major
# G major
# F major
# G major
# F major
# G major
# E- major
# F major
# B- major
# F major
# g minor
# G major
# E- major
# G major
# B- major
# G major
# A major
# G major
# G major
# G major
# F major
# G major
# G major
# F major
# E- major
# F major
# F major
# B- major
# G major
# F major
# g minor
# F major
# B- major
# B- major
# E- major
# C major
# G major
# B- major
# C major
# F major
# D major
# C major
# B- major
# B- major
# F major
# A major
# G major
# G major
# G major
# g minor
# G major
# F major
# F major
# F major
# F major
# G major
# G major
# F major
# F major
# G major
# C major
# G major
# A major
# C major
# G major
# G major
# F major
# D major
# G major
# F major
# G major
# F major
# G major
# g minor
# G major
# G major
# C major
# F major
# C major
# d minor
# G major
# G major
# e minor
# D major
# G major
# G major
# G major
# F major
# F major
# C major
# G major
# C major
# a minor
# g minor
# G major
# G major
# G major
# G major
# G major
# F major
# G major
# B- major
# F major
# F major
# E major
# F major
# G major
# G major
# G major
# G major
# C major
# F major
# C major
# C major
# G major
# G major
# G major
# F major
# G major
# G major
# F major
# G major
# G major
# A major
# d minor
# G major
# G major
# F major
# C major
# C major
# f minor
# G major
# F major
# F major
# G major
# B- major
# F major
# G major
# F major
# G major
# G major
# G major
# G major
# B- major
# F major
# C major
# F major
# G major
# A major
# F major
# G major
# F major
# a minor
# F major
# G major
# A major
# C major
# D major
# G major
# F major
# F major
# F major
# F major
# F major
# F major
# G major
# F major
# F major
# B- major
# E- major
# G major
# G major
# G major
# B- major
# F major
# F major
# F major
# d minor
# B- major
# C major
# a minor
# G major
# G major
# D major
# D major
# G major
# G major
# G major
# C major
# F major
# G major
# B- major
# G major
# G major
# G major
# E- major
# G major
# g minor
# F major
# D major
# F major
# D major
# G major
# G major
# F major
# F major
# C major
# D major
# F major
# C major
# G major
# F major
# a minor
# G major
# C major
# G major
# g minor
# A major
# F major
# F major
# D major
# F major
# E- major
# D major
# B- major
# F major
# B- major
# G major
# g minor
# F major
# G major
# C major
# A major
# F major
# E- major
# A major
# G major
# g minor
# F major
# G major
# C major
# F major
# F major
# G major
# E major
# G major
# G major
# G major
# C major
# C major
# B- major
# e minor
# G major
# G major
# A major
# g minor
# C major
# F major
# G major
# F major
# F major
# a minor
# G major
# C major
# G major
# G major
# G major
# F major
# G major
# G major
# G major
# G major
# C major
# A major
# F major
# G major
# G major
# D major
# C major
# G major
# F major
# F major
# G major
# D major
# C major
# B- major
# G major
# G major
# F major
# C major
# F major
# C major
# E- major
# G major
# G major
# G major
# E- major
# G major
# C major
# G major
# G major
# F major
# F major
# F major
# F major
# E major
# G major
# G major
# F major
# G major
# a minor
# G major
# G major
# G major
# F major
# C major
# G major
# D major
# G major
# C major
# F major
# G major
# G major
# F major
# F major
# G major
# C major
# B- major
# F major
# F major
# G major
# B- major
# C major
# C major
# G major
# A major
# G major
# C major
# D major
# G major
# F major
# F major
# g minor
# G major
# F major
# F major
# G major
# G major
# F major
# G major
# B- major
# F major
# G major
# F major
# F major
# C major
# D major
# F major
# G major
# G major
# F major
# C major
# G major
# F major
# G major
# G major
# E- major
# G major
# G major
# G major
# G major
# F major
# F major
# A major
# G major
# G major
# G major
# A major
# F major
# F major
# G major
# G major
# E- major
# F major
# C major
# G major
# g minor
# F major
# G major
# B- major
# G major
# F major
# G major
# G major
# G major
# B- major
# A major
# B- major
# F major
# F major
# G major
# G major
# D major
# G major
# C major
# G major
# G major
# G major
# A major
# G major
# E- major
# F major
# a minor
# F major
# B- major
# G major
# G major
# G major
# C major
# G major
# C major
# F major
# D major
# G major
# a minor
# G major
# D major
# G major
# A major
# G major
# C major
# G major
# G major
# E major
# G major
# F major
# F major
# C major
# F major
# A major
# C major
# G major
# D major
# F major
# F major
# G major
# F major
# F major
# F major
# F major
# F major
# f# minor
# G major
# A major
# g minor
# A major
# G major
# G major
# a minor
# B- major
# G major
# g minor
# G major
# F major
# G major
# g minor
# F major
# G major
# G major
# G major
# B- major
# G major
# g minor
# F major
# F major
# G major
# A major
# G major
# C major
# d minor
# A major
# G major
# F major
# F major
# g minor
# F major
# D major
# G major
# d minor
# G major
# G major
# e minor
# F major
# G major
# C major
# F major
# F major
# D major
# G major
# B- major
# F major
# G major
# F major
# D major
# D major
# B- major
# F major
# C major
# G major
# g minor
# G major
# A major
# B- major
# G major
# G major
# F major
# A major
# G major
# G major
# G major
# D major
# G major
# d minor
# F major
# F major
# F major
# A major
# G major
# F major
# G major
# G major
# G major
# G major
# G major
# G major
# C major
# G major
# F major
# E- major
# G major
# E- major
# A major
# F major
# G major
# B- major
# E- major
# G major
# D major
# G major
# G major
# F major
# G major
# G major
# F major
# G major
# F major
# B- major
# D major
# g minor
# E- major
# F major
# B- major
# F major
# F major
# g minor
# G major
# G major
# G major
# E- major
# G major
# F major
# G major
# F major
# G major
# F major
# F major
# G major
# C major
# F major
# F major
# C major
# E- major
# B- major
# G major
# G major
# D major
# C major
# F major
# D major
# A major
# G major
# a minor
# C major
# D major
# G major
# G major
# G major
# E- major
# g minor
# G major
# G major
# F major
# B- major
# C major
# C major
# F major
# B- major
# a minor
# G major
# B- major
# F major
# F major
# F major
# F major
# G major
# C major
# D major
# E- major
# C major
# B- major
# G major
# A major
# A- major
# F major
# F major
# D major
# G major
# F major
# D major
# g minor
# F major
# C major
# C major
# F major
# A major
# G major
# B- major
# C major
# G major
# F major
# F major
# G major
# G major
# G major
# C major
# F major
# G major
# F major
# G major
# G major
# B- major
# E- major
# C major
# C major
# F major
# C major
# G major
# G major
# F major
# D major
# G major
# G major
# F major
# G major
# G major
# E- major
# G major
# G major
# F major
# D major
# G major
# F major
# G major
# G major
# F major
# a minor
# g minor
# F major
# G major
# G major
# F major
# F major
# E major
# A major
# C major
# C major
# F major
# B- major
# E- major
# G major
# F major
# B- major
# F major
# F major
# F major
# F major
# F major
# F major
# G major
# D major
# F major
# G major
# B- major
# G major
# F major
# F major
# D major
# G major
# C major
# G major
# F major
# F major
# F major
# F major
# G major
# G major
# G major
# G major
# B- major
# B- major
# g minor
# G major
# C major
# F major
# F major
# G major
# d minor
# F major
# G major
# G major
# B- major
# G major
# G major
# D major
# G major
# G major
# G major
# G major
# G major
# G major
# D major
# E- major
# A major
# C major
# F major
# F major
# C major
# F major
# F major
# G major
# F major
# F major
# G major
# B- major
# F major
# G major
# G major
# G major
# a minor
# G major
# F major
# E- major
# B- major
# G major
# G major
# C major
# D major
# C major
# G major
# C major
# G major
# B- major
# C major
# B- major
# G major
# A major
# G major
# B- major
# G major
# F major
# f minor
# F major
# F major
# G major
# G major
# F major
# d minor
# B- major
# G major
# B- major
# F major
# E- major
# G major
# F major
# G major
# G major
# g minor
# C major
# B- major
# F major
# G major
# C major
# C major
# G major
# G major
# G major
# B- major
# G major
# G major
# F major
# G major
# F major
# G major
# B- major
# G major
# G major
# G major
# F major
# G major
# C major
# G major
# F major
# D major
# G major
# G major
# F major
# G major
# F major
# G major
# a minor
# G major
# F major
# G major
# g minor
# G major
# F major
# E- major
# E- major
# G major
# G major
# G major
# A major
# C major
# F major
# F major
# F major
# G major
# F major
# F major
# G major
# d minor
# G major
# F major
# G major
# G major
# E- major
# D major
# C major
# F major
# G major
# G major
# G major
# E- major
# D major
# D major
# C major
# G major
# F major
# D major
# d minor
# C major
# F major
# F major
# C major
# B- major
# G major
# G major
# G major
# G major
# F major
# C major
# D major
# F major
# F major
# G major
# F major
# F major
# G major
# F major
# F major
# G major
# F major
# F major
# F major
# F major
# C major
# G major
# F major
# G major
# F major
# F major
# F major
# G major
# a minor
# G major
# G major
# G major
# C major
# C major
# F major
# G major
# G major
# F major
# C major
# D major
# g minor
# g minor
# C major
# F major
# D major
# B- major
# a minor
# G major
# F major
# F major
# B- major
# G major
# G major
# F major
# E- major
# C major
# C major
# G major
# g minor
# F major
# F major
# F major
# F major
# a minor
# G major
# G major
# F major
# A major
# G major
# G major
# F major
# F major
# D major
# F major
# G major
# G major
# G major
# G major
# C major
# F major
# G major
# B- major
# F major
# F major
# B- major
# G major
# G major
# D major
# G major
# C major
# F major
# e minor
# F major
# g minor
# G major
# F major
# G major
# G major
# g minor
# G major
# A major
# A major
# F major
# G major
# B- major
# A major
# G major
# G major
# G major
# C major
# G major
# G major
# F major
# G major
# G major
# G major
# e minor
# E major
# G major
# G major
# G major
# F major
# B- major
# F major
# E major
# G major
# a minor
# C major
# D major
# F major
# G major
# G major
# G major
# D major
# B- major
# D major
# B- major
# F major
# B- major
# F major
# G major
# F major
# F major
# G major
# e minor
# G major
# G major
# E major
# F major
# G major
# e minor
# D major
# G major
# F major
# G major
# B- major
# F major
# G major
# B- major
# F major
# B- major
# G major
# a minor
# F major
# g minor
# D major
# F major
# C major
# F major
# F major
# C major
# F major
# g minor
# F major
# F major
# C major
# F major
# A major
# F major
# G major
# F major
# a minor
# C major
# G major
# G major
# G major
# F major
# G major
# G major
# g minor
# G major
# F major
# G major
# G major
# F major
# G major
# F major
# F major
# G major
# F major
# C major
# G major
# G major
# F major
# G major
# G major
# F major
# F major
# F major
# C major
# F major
# D major
# G major
# C major
# F major
# F major
# B- major
# F major
# B- major
# F major
# F major
# C major
# G major
# d minor
# F major
# C major
# G major
# G major
# F major
# G major
# F major
# F major
# G major
# a minor
# G major
# F major
# A major
# B- major
# F major
# G major
# G major
# C major
# G major
# F major
# G major
# G major
# F major
# F major
# A major
# F major
# G major
# G major
# G major
# E- major
# G major
# B- major
# B- major
# B- major
# B- major
# G major
# G major
# A major
# F major
# d minor
# B- major
# G major
# D major
# G major
# G major
# G major
# F major
# F major
# F major
# G major
# E major
# G major
# D major
# C major
# C major
# G major
# G major
# F major
# F major
# B- major
# E major
# F major
# G major
# G major
# F major
# E major
# G major
# C major
# G major
# F major
# C major
# G major
# G major
# G major
# G major
# F major
# G major
# F major
# A major
# G major
# E- major
# G major
# G major
# G major
# G major
# G major
# F major
# F major
# C major
# a minor
# G major
# F major
# C major
# G major
# G major
# F major
# F major
# C major
# G major
# G major
# G major
# A major
# e minor
# F major
# F major
# F major
# G major
# F major
# F major
# F major
# E- major
# F major
# F major
# G major
# F major
# G major
# F major
# a minor
# F major
# G major
# F major
# F major
# g minor
# G major
# F major
# F major
# F major
# F major
# F major
# A major
# F major
# F major
# F major
# G major
# G major
# G major
# B- major
# F major
# G major
# G major
# B- major
# C major
# D major
# d minor
# F major
# F major
# E- major
# G major
# E- major
# G major
# G major
# F major
# G major
# D major
# F major
# a minor
# C major
# F major
# F major
# F major
# F major
# G major
# G major
# G major
# G major
# B- major
# d minor
# G major
# G major
# G major
# G major
# d minor
# A major
# G major
# G major
# B- major
# F major
# g minor
# G major
# G major
# F major
# G major
# G major
# F major
# A major
# F major
# E- major
# C major
# C major
# D major
# G major
# F major
# G major
# G major
# C major
# F major
# G major
# D major
# G major
# F major
# F major
# G major
# F major
# F major
# F major
# G major
# F major
# g minor
# F major
# G major
# B- major
# E- major
# F major
# g minor
# G major
# C major
# G major
# C major
# D major
# F major
# G major
# F major
# B- major
# C major
# F major
# F major
# F major
# F major
# A major
# G major
# G major
# F major
# D major
# G major
# G major
# B- major
# F major
# a minor
# A major
# A major
# F major
# F major
# f minor
# F major
# D major
# D major
# A major
# B- major
# G major
# G major
# A major
# G major
# E- major
# D major
# G major
# F major
# D major
# F major
# F major
# G major
# C major
# F major
# F major
# G major
# D major
# F major
# G major
# G major
# E- major
# G major
# F major
# C major
# G major
# G major
# F major
# F major
# C major
# G major
# G major
# B- major
# F major
# B- major
# D major
# F major
# F major
# g minor
# F major
# C major
# G major
# F major
# F major
# G major
# G major
# F major
# G major
# E- major
# G major
# F major
# B- major
# G major
# F major
# d minor
# A major
# G major
# G major
# B- major
# D major
# e minor
# G major
# G major
# F major
# G major
# F major
# F major
# G major
# G major
# G major
# G major
# G major
# f minor
# C major
# G major
# D major
# C major
# G major
# B- major
# g minor
# B- major
# F major
# F major
# G major
# F major
# F major
# C major
# G major
# C major
# E major
# B- major
# G major
# G major
# G major
# D major
# G major
# a minor
# D major
# C major
# C major
# D major
# G major
# a minor
# D major
# G major
# D major
# F major
# G major
# G major
# C major
# F major
# F major
# F major
# G major
# G major
# E- major
# G major
# C major
# F major
# G major
# F major
# F major
# F major
# G major
# C major
# G major
# f minor
# B- major
# G major
# F major
# F major
# B- major
# F major
# C major
# F major
# F major
# F major
# G major
# G major
# G major
# G major
# C major
# G major
# D major
# F major
# G major
# a minor
# F major
# e minor
# C major
# g minor
# G major
# B- major
# g minor
# d minor
# F major
# G major
# G major
# G major
# F major
# G major
# D major
# G major
# d minor
# D major
# G major
# F major
# G major
# G major
# F major
# a minor
# F major
# G major
# F major
# F major
# G major
# F major
# B- major
# D major
# D major
# B- major
# C major
# C major
# G major
# G major
# F major
# G major
# D major
# G major
# C major
# F major
# G major
# C major
# D major
# G major
# F major
# G major
# G major
# G major
# d minor
# G major
# G major
# D major
# G major
# G major
# F major
# F major
# F major
# g minor
# G major
# G major
# G major
# C major
# e minor
# G major
# g minor
# G major
# F major
# G major
# D major
# F major
# G major
# F major
# G major
# G major
# D major
# G major
# F major
# G major
# F major
# G major
# F major
# F major
# g minor
# G major
# F major
# g minor
# G major
# C major
# G major
# D major
# C major
# F major
# F major
# G major
# F major
# g minor
# G major
# G major
# F major
# G major
# G major
# d minor
# G major
# G major
# F major
# F major
# B- major
# C major
# G major
# G major
# G major
# a minor
# F major
# G major
# D major
# G major
# G major
# E- major
# F major
# F major
# G major
# G major
# a minor
# F major
# e minor
# g minor
# G major
# F major
# F major
# C major
# G major
# f minor
# G major
# F major
# F major
# G major
# g minor
# F major
# E major
# G major
# F major
# d minor
# G major
# g minor
# G major
# G major
# G major
# B- major
# G major
# G major
# B- major
# a minor
# d minor
# d minor
# G major
# G major
# F major
# G major
# g minor
# C major
# G major
# G major
# F major
# G major
# g minor
# g minor
# G major
# F major
# C major
# G major
# G major
# C major
# B- major
# G major
# G major
# F major
# D major
# G major
# G major
# G major
# g minor
# F major
# F major
# F major
# D major
# E major
# G major
# G major
# G major
# G major
# G major
# a minor
# F major
# g minor
# C major
# G major
# d minor
# C major
# G major
# C major
# C major
# F major
# C major
# C major
# G major
# g minor
# G major
# a minor
# G major
# G major
# C major
# G major
# G major
# G major
# A major
# A major
# G major
# G major
# e minor
# F major
# G major
# F major
# g minor
# F major
# F major
# G major
# G major
# C major
# F major
# G major
# C major
# F major
# B- major
# D major
# F major
# g minor
# C major
# F major
# G major
# f minor
# G major
# G major
# G major
# G major
# F major
# F major
# D major
# G major
# G major
# G major
# G major
# F major
# a minor
# G major
# G major
# G major
# G major
# G major
# F major
# G major
# g minor
# g minor
# G major
# G major
# F major
# D major
# F major
# F major
# G major
# B- major
# f minor
# F major
# F major
# G major
# G major
# G major
# G major
# g minor
# G major
# C major
# C major
# G major
# C major
# G major
# G major
# G major
# G major
# F major
# G major
# F major
# F major
# G major
# G major
# G major
# C major
# G major
# A major
# G major
# F major
# F major
# G major
# G major
# G major
# g minor
# F major
# f minor
# d minor
# F major
# G major
# F major
# G major
# G major
# G major
# G major
# G major
# d minor
# F major
# G major
# G major
# G major
# C major
# c minor
# B- major
# G major
# G major
# G major
# G major
# G major
# G major
# G major
# d minor
# G major
# G major
# G major
# G major
# G major
# F major
# C major
# G major
# G major
# F major
# d minor
# G major
# C major
# G major
# F major
# G major
# G major
# G major
# G major
# G major
# G major
# G major
# g minor
# G major
# D major
# C major
# g minor
# g minor
# F major
# C major
# G major
# g minor
# C major
# C major
# E major
# G major
# G major
# a minor
# G major
# D major
# F major
# G major
# G major
# D major
# F major
# F major
# G major
# d minor
# G major
# G major
# G major
# G major
# C major
# G major
# C major
# G major
# G major
# a minor
# F major
# a minor
# G major
# G major
# G major
# d minor
# G major
# F major
# F major
# G major
# G major
# G major
# F major
# G major
# G major
# G major
# F major
# G major
# G major
# C major
# G major
# G major
# G major
# G major
# C major
# G major
# G major
# G major
# C major
# F major
# C major
# G major
# G major
# G major
# G major
# G major
# G major
# G major
# G major
# G major
# F major
# g minor
# g minor
# F major
# D major
# G major
# G major
# e minor
# G major
# F major
# G major
# G major
# G major
# G major
# g minor
# G major
# F major
# A- major
# G major
# B- major
# G major
# A major
# G major
# G major
# G major
# G major
# G major
# C major
# d minor
# D major
# G major
# C major
# G major
# a minor
# G major
# C major
# G major
# G major
# G major
# G major
# G major
# G major
# F major
# G major
# d minor
# G major
# e minor
# G major
# F major
# C major
# G major
# G major
# F major
# F major
# e minor
# g minor
# F major
# g minor
# C major
# G major
# G major
# F major
# g minor
# B- major
# a minor
# G major
# g minor
# e minor
# G major
# C major
# B- major
# E- major
# F major
# F major
# g minor
# g minor
# G major
# G major
# F major
# D major
# G major
# G major
# D major
# g minor
# g minor
# F major
# G major
# G major
# G major
# G major
# G major
# G major
# G major
# F major
# G major
# B- major
# g minor
# G major
# E- major
# G major
# F major
# G major
# G major
# G major
# G major
# G major
# G major
# F major
# F major
# F major
# g minor
# G major
# F major
# G major
# C major
# C major
# B- major
# d minor
# F major
# g minor
# G major
# D major
# G major
# G major
# C major
# F major
# F major
# F major
# G major
# G major
# D major
# d minor
# d minor
# F major
# F major
# C major
# G major
# G major
# G major
# B- major
# G major
# F major
# G major
# G major
# G major
# G major
# G major
# G major
# e minor
# d minor
# F major
# D major
# d minor
# G major
# F major
# F major
# G major
# g minor
# G major
# e- minor
# F major
# B- major
# G major
# G major
# G major
# G major
# F major
# a minor
# G major
# G major
# F major
# F major
# F major
# g minor
# F major
# G major
# F major
# C major
# G major
# G major
# G major
# B- major
# F major
# G major
# G major
# F major
# a minor
# G major
# G major
# a minor
# G major
# G major
# F major
# F major
# C major
# G major
# F major
# g minor
# G major
# A major
# G major
# d minor
# F major
# g minor
# E- major
# C major
# g minor
# G major
# G major
# C major
# G major
# G major
# F major
# F major
# G major
# G major
# G major
# G major
# B- major
# F major
# C major
# F major
# e minor
# b minor
# C major
# e minor
# F major
# e minor
# g minor
# C major
# e minor

# %%
# put all the songs in single file

songs = create_single_file(SAVE_DIR,SINGLE_FILE)

# %%
import json
def mapping(songs,mapping_path):
  #identify the vocab and save them to a json
  mappings = {}
  songs = songs.split()
  vocabulary = list(set(songs))
  for i , symbol in enumerate(vocabulary):
    mappings[symbol] = i

  with open(mapping_path,"w") as f:
    json.dump(mappings,f,indent=4)

# %%
MAPPING_PATH = "mapping.json"
mapping(songs,MAPPING_PATH)

# %%
# convert the songs to the integers
import numpy as np
import json
import tensorflow.keras as keras
def convert_songs_to_int(songs):
  # load the mappings (json)
  # cast song string to list
  # map songs to int

  int_songs = []

  with open("mapping.json","r") as f :
    mappings = json.load(f)

  songs = songs.split()

  for symbol in songs:
    int_songs.append(mappings[symbol])

  return int_songs

def load(file_path):
    with open(file_path, "r") as fp:
        song = fp.read()
    return song

def generate_training_sequences(sequence_length):
    """Create input and output data samples for training. Each sample is a sequence.

    :param sequence_length (int): Length of each sequence. With a quantisation at 16th notes, 64 notes equates to 4 bars

    :return inputs (ndarray): Training inputs
    :return targets (ndarray): Training targets
    """

    # load songs and map them to int
    songs = load("file_dataset.txt")
    int_songs = convert_songs_to_int(songs)

    inputs = []
    targets = []

    # generate the training sequences
    num_sequences = len(int_songs) - sequence_length
    for i in range(num_sequences):
        inputs.append(int_songs[i:i+sequence_length])
        targets.append(int_songs[i+sequence_length])

    # one-hot encode the sequences
    # the error was here, as the vocab size was too small we change to max
    # to take into account for every possible note
    #vocabulary_size = len(set(int_songs))
    vocabulary_size = max(int_songs) # change is here

    # inputs size: (# of sequences, sequence length, vocabulary size)
    # we also add +1 here to prevent index error
    inputs = keras.utils.to_categorical(inputs, num_classes=vocabulary_size+1) # change is here
    targets = np.array(targets)

    return inputs, targets

# %%
Sequencelength = 64
input,target = generate_training_sequences(Sequencelength)

# %%
input.shape , target.shape
# Out:
# ((2512, 64, 45), (2512,))

# %%
import tensorflow.keras as keras

def build_model(op_units,num_units,loss,learning_rate):
  inputs = keras.layers.Input((None,op_units))
  x = keras.layers.LSTM(num_units[0])(inputs)
  x = keras.layers.Dropout(0.2)(x)

  outputs = keras.layers.Dense(op_units,activation="softmax")(x)
  model = keras.Model(inputs,outputs)
  model.compile(loss=loss,optimizer="adam",metrics=["accuracy"])
  model.summary()
  return model


def train():

  OUTPUT_UNITS = 45 # total map size (45 unique char)
  NUM_UNITS = [256]
  LOSS = "sparse_categorical_crossentropy"
  LR = 0.001
  EPOCHS = 45
  BATCH_SIZE = 256

  #build model
  model = build_model(OUTPUT_UNITS,NUM_UNITS,LOSS,LR)

  # train the model
  model.fit(input,target,batch_size=BATCH_SIZE,epochs=EPOCHS)

  # save the model
  model.save("model.keras")

# %%
train()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ input_layer_2 (InputLayer)           │ (None, None, 45)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ lstm_1 (LSTM)                        │ (None, 256)                 │         309,248 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 45)                  │          11,565 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 320,813 (1.22 MB)
#  Trainable params: 320,813 (1.22 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 513ms/step - accuracy: 0.4768 - loss: 3.3303
# Epoch 2/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 493ms/step - accuracy: 0.6508 - loss: 1.5647
# Epoch 3/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.7255 - loss: 1.2690
# Epoch 4/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.7440 - loss: 1.1735
# Epoch 5/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 523ms/step - accuracy: 0.7325 - loss: 1.1909
# Epoch 6/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 521ms/step - accuracy: 0.7386 - loss: 1.1472
# Epoch 7/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.7461 - loss: 1.1223
# Epoch 8/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 488ms/step - accuracy: 0.7474 - loss: 1.1336
# Epoch 9/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 472ms/step - accuracy: 0.7525 - loss: 1.1110
# Epoch 10/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step - accuracy: 0.7551 - loss: 1.0962
# Epoch 11/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 515ms/step - accuracy: 0.7511 - loss: 1.0771
# Epoch 12/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.7680 - loss: 1.0228
# Epoch 13/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 515ms/step - accuracy: 0.7475 - loss: 1.0568
# Epoch 14/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 461ms/step - accuracy: 0.7534 - loss: 1.0624
# Epoch 15/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 480ms/step - accuracy: 0.7643 - loss: 1.0303
# Epoch 16/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 474ms/step - accuracy: 0.7526 - loss: 1.0314
# Epoch 17/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 462ms/step - accuracy: 0.7527 - loss: 1.0275
# Epoch 18/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 516ms/step - accuracy: 0.7478 - loss: 1.0582
# Epoch 19/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 517ms/step - accuracy: 0.7509 - loss: 1.0132
# Epoch 20/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.7523 - loss: 1.0249
# Epoch 21/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 490ms/step - accuracy: 0.7636 - loss: 0.9699
# Epoch 22/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 464ms/step - accuracy: 0.7696 - loss: 0.9305
# Epoch 23/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 458ms/step - accuracy: 0.7516 - loss: 0.9548
# Epoch 24/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 513ms/step - accuracy: 0.7617 - loss: 0.9113
# Epoch 25/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 460ms/step - accuracy: 0.7754 - loss: 0.8918
# Epoch 26/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 522ms/step - accuracy: 0.7643 - loss: 0.9024
# Epoch 27/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 509ms/step - accuracy: 0.7671 - loss: 0.8794
# Epoch 28/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 543ms/step - accuracy: 0.7766 - loss: 0.8135
# Epoch 29/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 556ms/step - accuracy: 0.7621 - loss: 0.8450
# Epoch 30/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 544ms/step - accuracy: 0.7759 - loss: 0.7969
# Epoch 31/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 467ms/step - accuracy: 0.7550 - loss: 0.8318
# Epoch 32/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 528ms/step - accuracy: 0.7718 - loss: 0.7993
# Epoch 33/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 11s 606ms/step - accuracy: 0.7649 - loss: 0.8029
# Epoch 34/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 7s 662ms/step - accuracy: 0.7734 - loss: 0.7285
# Epoch 35/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 9s 588ms/step - accuracy: 0.7771 - loss: 0.7125
# Epoch 36/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 564ms/step - accuracy: 0.7774 - loss: 0.6973
# Epoch 37/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 536ms/step - accuracy: 0.7810 - loss: 0.6502
# Epoch 38/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 461ms/step - accuracy: 0.7669 - loss: 0.6793
# Epoch 39/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 472ms/step - accuracy: 0.7688 - loss: 0.6983
# Epoch 40/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 471ms/step - accuracy: 0.7731 - loss: 0.6598
# Epoch 41/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 467ms/step - accuracy: 0.7754 - loss: 0.6371
# Epoch 42/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 6s 540ms/step - accuracy: 0.7794 - loss: 0.6231
# Epoch 43/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 10s 539ms/step - accuracy: 0.7924 - loss: 0.6041
# Epoch 44/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 465ms/step - accuracy: 0.7979 - loss: 0.5921
# Epoch 45/45
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 5s 507ms/step - accuracy: 0.7870 - loss: 0.6173

# %%
import tensorflow.keras as keras

class Melodygenerator():
  def __init__(self,model_path):
    self.model_path = model_path
    self.model = keras.models.load_model("model.keras")

    with open("mapping.json","r") as f:
      self.mappings = json.load(f)

    self.start_symbols = ["/"] * Sequencelength


  def sample_with_temperature(self,probabilities,temperature):
    # if temp -> infinity all the values tends to have uniform pdf
    # if temp -> 0 then the particular value is totally dominant over all approx = 1
    predictions = np.log(probabilities) / temperature
    probabilities = np.exp(predictions)/np.sum(np.exp(predictions))
    choices = range(len(probabilities))
    index = np.random.choice(choices,p=probabilities) # to each item of the choices we have their corresponding prob output that

    return index



  def generate_melody(self,seed,num_steps,max_seqlen,temperature):

    # create seed with start symbols
    seed = seed.split()
    melody = seed
    seed = self.start_symbols + seed

    # map seed to int
    seed= [self.mappings[symbols] for symbols in seed]

    for _ in range(num_steps):
      # limit the seed to max_seq_len
      seed_list  = seed[-max_seqlen:] # last relevent steps are considered
      #one hot encoded
      oh_seed = keras.utils.to_categorical(seed_list,num_classes=len(self.mappings))
      #to make a prediction we have to add extra dimension
      oh_seed = oh_seed[np.newaxis,...]


      probabilities = self.model.predict(oh_seed)[0]
      output_int = self.sample_with_temperature(probabilities,temperature)

      seed.append(output_int)

      output_symbol = [k for k,v in self.mappings.items() if v == output_int][0]

      # we are using temperature sampling over just showing the highest prob value

      # CHECK if we are at the end of the song if so then exit
      if output_symbol=="/":
        break

      melody.append(output_symbol)
    return melody

# %%
mlg = Melodygenerator("model.keras")
seed = "55 _ _ _ 64 _ _ _ 64 _ 64"
melody = mlg.generate_melody(seed,num_steps = 500, max_seqlen=  64, temperature = 0.7)
print(melody)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 81ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 59ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 133ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 71ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 67ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 55ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 70ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 52ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 40ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# ['55', '_', '_', '_', '64', '_', '_', '_', '64', '_', '64', '_', '64', '_', '64', '_', '64', '_', '62', '_', '69', '_', '62', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '67', '_', '67', '_', '_', '_', '_', '_', '_', '_', '65', '_', '67', '_', '62', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '62', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '67', '_', '62', '_', '64', '_', '_', '_', '72', '_', '69', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '67', '_', '_', '_', '_', '_', '_', '_', '69', '_', '_', '_', '71', '_', '69', '_', '69', '_', '69', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '64', '_', '71', '_', '_', '_', '69', '_', '_', '_', '67', '_', '_', '_', '71', '_', '67', '_', '71', '_', '_', '_', '69', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '64', '_', '74', '_', '_', '_', '_', '_', '_', '_', '72', '_', '_', '_', '67', '_', '71', '_', '_', '_', '_', '_', '_', '_', '76', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '74', '_', '_', '_', '69', '_', '_', '_', '_', '_', '_', '_', '72', '_', '69', '_', '_', '_', '67', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '64', '_', '_', '_', '_', '_', '_', '_', '_', '_', '67', '_', '_', '_', '_', '_', '_', '_', '_', '_', '67', '_', '_', '_', '67', '_', '67', '_', '_', '_', '71', '_', '71', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '67', '_', '_', '_', '_', '_', '64', '_', '69', '_', '67', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '69', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '67', '_', '67', '_', '_', '_', '_', '_', '71', '_', '69', '_', '71', '_', '72', '_', '_', '_', '_', '_', '_', '_', '_', '_', '64', '_', '74', '_', '_', '_', '_', '_', '74', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', 'r', '_', '_', '_', '_', '_', '69', '_', '72', '_', '_', '_', '71', '_', '_', '_', '_', '_', '_', '_', '_', '_', 'r', '_', '_', '_', '_', '_', '74', '_', '_', '_', '72', '_', '_', '_', '69', '_', '69', '_', '71', '_', 'r', '_', '_', '_', '_', '_', '72', '_', '74', '_', '72', '_', '_', '_', '71', '_', '_', '_', '67', '_', '_', '_', '_', '_', '67', '_', '_', '_', '_', '_', '_', '_', '_', '_', '72', '_', '72', '_', '69', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '_', '74', '_', '_', '_', '76', '_', '72', '_', '_', '_', '72', '_', '_', '_', '_', '_', '_']

# %%
# Visualize the melody
import music21 as m21
def save_melody(melody,format = "midi",file_name = "mel.midi",step_duration = 0.25):

  # create a music 21 stream
  stream = m21.stream.Stream()

  # parse all the symbols in melody and create note/rest objects
  start_symbol = None
  step_counter = 1

  for i,symbol in enumerate(melody):

    # we have note/rest
    if symbol != "_" or i+1 ==len(melody):
      if start_symbol is not None:
        quarter_length_duration = step_duration * step_counter
        # if rest
        if start_symbol == "r":
          m21_event = m21.note.Rest(quarterLength=quarter_length_duration)
        # if note
        else:
          m21_event = m21.note.Note(int(start_symbol),quarterLength=quarter_length_duration)
        stream.append(m21_event)
        # reset
        step_counter = 1
      start_symbol = symbol

    # we have "_"  it is prolongation sign
    else:
      step_counter+=1

  stream.write(format,file_name)

# %%
save_melody(melody)
